# %% [markdown]
# <div style="width:100%; background-color:#181818; color:#f1f1f1; padding:30px 0; text-align:center; border-radius:10px;">
#
#   <img src="https://media4.giphy.com/media/v1.Y2lkPTc5MGI3NjExcXVodWNsM3Bia3duZGljZzRqMTI2MGFiZjlkZzBwcmhuaWxydjlpaiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/AOSwwqVjNZlDO/giphy.gif" alt="Beam Oscillation" width="400" style="border-radius:10px;">
#
#   <h3 style="color:#ffffff; margin-top:15px;"><b>Basic Examples of Coding with Jupyter and Python</b></h3>
#
#   <p><b>Author:</b> <a href="http://caceli.net/" style="color:#3ea6ff; text-decoration:none;">Msc. Ing. Carlos Andrés Celi Sánchez</a></p>
#   <p><b>Course:</b> Matrix Analisys</p>
#   <p><b>Year:</b> MARCH - 2026</p>
#
# </div>

# %% [markdown]
# #### Introduction

# %% [markdown]
# This notebook presents a very first approach to Python coding using Jupyter Notebook as an educational environment.
# The objective is to help students become familiar with simple commands, variable definition, array manipulation, loops, and basic output visualization.
#
# Although the examples are intentionally simple, they represent the foundation for more advanced applications that will later be used in structural engineering, numerical methods, and matrix-based analysis.

# %% [markdown]
# #### Importing Libraries

# %% [markdown]
# The first step in many Python workflows is importing the required libraries.
# In this notebook, we start with **NumPy**, which is one of the most important libraries for scientific computing.
#
# NumPy allows us to:
# - perform numerical operations efficiently,
# - define vectors and matrices,
# - create arrays automatically, and
# - prepare the basis for future structural and mathematical applications.

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
import numpy as np
import sympy as sp
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Simple Console Messages

# %% [markdown]
# Python allows us to print messages in the output area in order to follow the execution of a script.
# This is very useful when we want to organize a numerical routine step by step and identify whether the process is running correctly.
#
# In the following example, colored text and emojis are used only as a visual aid to make the output more intuitive and easier to read.

# %%
print("\033[1;36m📌 Step 1: Creating model\033[0m")
print("\033[1;32m✅ Step 2: Analysis completed\033[0m")
print("\033[1;33m⚠️ Step 3: Review results carefully\033[0m")
print("\033[1;31m❌ Step 4: Convergence not achieved\033[0m")
# Out:
# 📌 Step 1: Creating model
# ✅ Step 2: Analysis completed
# ⚠️ Step 3: Review results carefully
# ❌ Step 4: Convergence not achieved

# %% [markdown]
# #### Basic Variables and Data Types
#
# A Python script is built from variables that store different kinds of information.
# These variables may represent numerical values, text, vectors, matrices, or more complex data structures.
#
# In the next example, we define:
# - a numerical result,
# - a text variable, and
# - an array of values.
#
# This helps illustrate how Python can handle different types of information within the same notebook.

# %% [markdown]
# #### Basic Use of Loops
#
# Loops are essential in programming because they allow us to repeat instructions automatically.
# Instead of writing the same command several times, we can use a loop to construct vectors, fill arrays, or process data step by step.
#
# The following examples show two simple approaches:
# - filling a NumPy array,
# - and building a Python list progressively.

# %% [markdown]
# #### Manual and Automatic Matrix Construction
#
# Matrices can be created manually by directly specifying their entries, or automatically by using loops and numerical functions.
# Both approaches are useful in engineering and scientific programming.
#
# The manual definition is convenient for small examples and for checking results by hand, while the automatic construction becomes much more efficient when dealing with larger systems or repetitive patterns.

# %%
from repo_maxtrix_analisys import *

# %%
a  =  np.sum(2+3)
print("a = ",a)
b  = 'hi'
print('b = ', b)
c = np.array([1,2,3,4])
print('c is', c.astype, 'which value is =', c)

#--- Basic loop for array construction
cc = np.zeros(4)
for i in np.arange(1, 4, 1):
    cc[i] = i+1
cc[0] = 1

#--- Basic loop for array construction
dd = []
for j in np.arange(1,4+1,1):
    dd.append(j)

print('cc = ', cc, ', dd = ', dd)

manu = np.array([[1,5,9,13],[2,6,10,14],[3,7,11,15],[4,8,12,16]])

#--- Basic loop for array construction "Matrix"
auto = np.zeros([4,4])
i = 0
for j in np.arange(1,4+1,1):
    auto[i,:] = np.linspace(j,j+12,4)
    i = i+1

print('\033[1;32m Manual Matrix Array : \033[0m\n', manu)
print('\033[1;36m Automatic Matrix Array : \033[0m\n', auto)
# Out:
# a =  5
# b =  hi
# c is <built-in method astype of numpy.ndarray object at 0x000002187CA9C810> which value is = [1 2 3 4]
# cc =  [1. 2. 3. 4.] , dd =  [1, 2, 3, 4]
#  Manual Matrix Array :
#  [[ 1  5  9 13]
#  [ 2  6 10 14]
#  [ 3  7 11 15]
#  [ 4  8 12 16]]
#  Automatic Matrix Array :
#  [[ 1.  5.  9. 13.]
#  [ 2.  6. 10. 14.]
#  [ 3.  7. 11. 15.]
#  [ 4.  8. 12. 16.]]

# %%
def matriz(hola):
    auto = np.zeros([4,4])
    i = 0
    for j in np.arange(1,4+1,1):
        auto[i,:] = np.linspace((j * hola),(j * hola) +12,4)
        i = i+1
   
    return auto

# %%
resul = matriz(100)
print('\033[1;36m Automatic Matrix Array : \033[0m\n', resul)
pepito = matriz(1)
print('\033[1;36m Automatic Matrix Array : \033[0m\n', pepito)
# Out:
#  Automatic Matrix Array :
#  [[100. 104. 108. 112.]
#  [200. 204. 208. 212.]
#  [300. 304. 308. 312.]
#  [400. 404. 408. 412.]]
#  Automatic Matrix Array :
#  [[ 1.  5.  9. 13.]
#  [ 2.  6. 10. 14.]
#  [ 3.  7. 11. 15.]
#  [ 4.  8. 12. 16.]]

# %%
h = []
for hola in np.arange(1, 3, 1):
    h.append(matriz(hola))

z = np.vstack(h)

# %%
print('\033[1;36m Automatic Matrix Array : \033[0m\n', z)
# Out:
#  Automatic Matrix Array :
#  [[ 1.  5.  9. 13.]
#  [ 2.  6. 10. 14.]
#  [ 3.  7. 11. 15.]
#  [ 4.  8. 12. 16.]
#  [ 2.  6. 10. 14.]
#  [ 4.  8. 12. 16.]
#  [ 6. 10. 14. 18.]
#  [ 8. 12. 16. 20.]]

# %% [markdown]
# * Use of Class

# %%
ejemplo1 = SimpleMatrixStack(3)
auto = ejemplo1.matriz()
auto
# Out:
# array([[ 3.,  7., 11., 15.],
#        [ 6., 10., 14., 18.],
#        [ 9., 13., 17., 21.],
#        [12., 16., 20., 24.]])

# %% [markdown]
# #### Inverse matrix calculation

# %%
EI = sp.Symbol('EI')
AE = sp.Symbol('AE')
GA = sp.Symbol('GA')
f = sp.Symbol('f')
L = sp.Symbol('L')


F = sp.Matrix([[L/EI, L**2 / (2*EI), 0],
              [L**2 / (2*EI), L**3 / (3*EI) + L*f / (GA), 0],
              [0, 0, L/AE]])

K = F**-1
K
# Out:
# Matrix([
# [(12*EI**2*f + 4*EI*GA*L**2)/(12*EI*L*f + GA*L**3),   -6*EI*GA/(12*EI*f + GA*L**2),    0],
# [                     -6*EI*GA/(12*EI*f + GA*L**2), 12*EI*GA/(12*EI*L*f + GA*L**3),    0],
# [                                                0,                              0, AE/L]])

# %% [markdown]
# #### Stiffness Matrix in Local Coordinates (RMF)
# ![alt text](image.png)
# ![alt text](image-1.png)

# %% [markdown]
# ##### Data

# %%
A = 0.3*0.3
I = 0.3**4/12
E = 2000000
u = 0.2
G = E/(2*(1+u))
L = 5
f = 6/5

D1 = 0.01
D2 = -0.03
D3 = 0.0002

# %% [markdown]
# ##### Stiffness Matrix in Local Coordinates (RMF)

# %% [markdown]
# * Conssiderering all deformation (V+M)

# %%
StiffnessMatrix = StiffnessMatrix_simple(A,I,E,L,G,f)
kl = StiffnessMatrix.stiffness_matrix_Element_RMF_L()
kl_df = pd.DataFrame(kl)
kl_df
# Out:
#          0           1            2        3           4            5
# 0  36000.0    0.000000     0.000000 -36000.0    0.000000     0.000000
# 1      0.0  128.270096   320.675239      0.0 -128.270096   320.675239
# 2      0.0  320.675239  1071.688098      0.0 -320.675239   531.688098
# 3 -36000.0    0.000000     0.000000  36000.0    0.000000     0.000000
# 4      0.0 -128.270096  -320.675239      0.0  128.270096  -320.675239
# 5      0.0  320.675239   531.688098      0.0 -320.675239  1071.688098

# %% [markdown]
# * Considering onlt bending deformation (M)

# %%
StiffnessMatrixF = StiffnessMatrix_simple(A,I,E,L,G,0)
klF = StiffnessMatrixF.stiffness_matrix_Element_RMF_L()
klF_df = pd.DataFrame(klF)
klF_df
# Out:
#          0      1       2        3      4       5
# 0  36000.0    0.0     0.0 -36000.0    0.0     0.0
# 1      0.0  129.6   324.0      0.0 -129.6   324.0
# 2      0.0  324.0  1080.0      0.0 -324.0   540.0
# 3 -36000.0    0.0     0.0  36000.0    0.0     0.0
# 4      0.0 -129.6  -324.0      0.0  129.6  -324.0
# 5      0.0  324.0   540.0      0.0 -324.0  1080.0

# %% [markdown]
# ##### Internal Force Vector in Local Coordinates (RMF)

# %%
d1 = 0
d2 = 0
d3 = 0
d4 = D1
d5 = D2
d6 = D3
delta = np.array([d1, d2, d3, d4, d5, d6])
delta_df = pd.DataFrame(delta, columns=['Displacements'])
delta_df
# Out:
#    Displacements
# 0         0.0000
# 1         0.0000
# 2         0.0000
# 3         0.0100
# 4        -0.0300
# 5         0.0002

# %% [markdown]
# * Considering all deformation (V+M)

# %%
P = kl @ delta
P_df = pd.DataFrame(P, columns=['Internal Forces'])
P_df
# Out:
#    Internal Forces
# 0      -360.000000
# 1         3.912238
# 2         9.726595
# 3       360.000000
# 4        -3.912238
# 5         9.834595

# %% [markdown]
# * Considerering only deformation by bending (M)

# %%
PF = klF @ delta
PF_df = pd.DataFrame(PF, columns=['Internal Forces'])
PF_df
# Out:
#    Internal Forces
# 0        -360.0000
# 1           3.9528
# 2           9.8280
# 3         360.0000
# 4          -3.9528
# 5           9.9360

# %% [markdown]
# * Example of basic plotting

# %%
x = np.array(np.random.rand(100))
y = np.array(np.random.rand(100))

fig, ax = plt.subplots(1,1, figsize=(16,9))
ax.plot(x,y, lw = 1, ls = '--', color = [0,0,0], marker = 'o',
        markersize = 10, markerfacecolor = [1,0,0],
        label = 'Randoms numbers')
ax.set_xlabel('x numbers')
ax.set_ylabel('y number')
ax.set_title('RAMDOM NUMBERS', fontsize = 15, fontweight = 'bold', color = [0,0,1])
ax.legend()
plt.show()

# %% [markdown]
# * Visual Representation of Matrix (all deformation)

# %%
D2matrix = M_visual_2D_3D(kl)
plot2d = D2matrix.M_visual()

# %% [markdown]
# * Visual Representation of Matrix (only bending deformation)

# %%
D2matrixF = M_visual_2D_3D(klF)
plot2dF = D2matrixF.M_visual()

# %% [markdown]
# #### Stiffness Matrix in Local Coordinates (RMF), include sherar deformation and rigid extrems

# %% [markdown]
# ##### Data

# %%
A = 0.3*0.3
I = 0.3**4/12
E = 2000000
u = 0.2
G = E / (1.0 + 2 * u)
L = 5
f = 6/5
da = 0.00
db = 0.00

# %%
Ejemplo = StiffnessMatrix_simple(A,I,E,L,G,f,da,db)
ke = Ejemplo.stiffness_matrix_Element_RMF_L()
Tr = Ejemplo.transform_matrix_df_to_indf()
print(ke)
# Out:
# [[ 36000.              0.              0.         -36000.
#        0.              0.        ]
#  [     0.            128.82089125    322.05222812      0.
#     -128.82089125    322.05222812]
#  [     0.            322.05222812   1075.13057031      0.
#     -322.05222812    535.13057031]
#  [-36000.              0.              0.          36000.
#        0.              0.        ]
#  [     0.           -128.82089125   -322.05222812      0.
#      128.82089125   -322.05222812]
#  [     0.            322.05222812    535.13057031      0.
#     -322.05222812   1075.13057031]]

# %% [markdown]
# ##### Stiffness Matrix in Local Coordinates (RMF), include sherar deformation and rigid extrems
#
# $$
# K_{er} = T \, K_e \, T^{\mathsf{T}}
# $$
#
# Where:
#
# - $K_{er}$ is the element stiffness matrix expressed in the global reference system.
# - $T$ is the coordinate transformation matrix from local to global axes.
# - $K_e$ is the element stiffness matrix expressed in the local reference system.
# - $T^{\mathsf{T}}$ is the transpose of the transformation matrix.

# %% [markdown]
# ![alt text](image-2.png)

# %% [markdown]
# #### **Local Stiffness Matrix of a 2D MF Element**
# ---
#
# For a prismatic **2D MF (Moment Frame) element** considering **axial deformation, flexural deformation, shear deformation**, and the presence of **rigid end offsets**, the **local stiffness matrix** is written in a generalized form as:
#
# $$
# \mathbf{K}_e =
# \begin{bmatrix}
#  r      & 0        & 0        & -r     & 0         & 0 \\
#  0      & t'       & b''      & 0      & -t'       & b''' \\
#  0      & b''      & k''      & 0      & -b''      & a''' \\
#  -r     & 0        & 0        & r      & 0         & 0 \\
#  0      & -t'      & -b''     & 0      & t'        & -b''' \\
#  0      & b'''     & a'''     & 0      & -b'''     & k'''
# \end{bmatrix}
# $$
#
# This matrix establishes the standard linear relationship:
#
# $$
# \mathbf{F}_e = \mathbf{K}_e \, \mathbf{U}_e
# $$
#
# Where:
# - $\mathbf{F}_e$ is the **local nodal force vector** of the element,
# - $\mathbf{U}_e$ is the **local nodal displacement vector**,
# - $\mathbf{K}_e$ is the **local stiffness matrix** of the MF element.
#
# The six degrees of freedom associated with the element are:
# - Axial displacement at node $A$, $\Delta x_A$
# - Transverse displacement at node $A$, $\Delta y_A$
# - Rotation at node $A$, $\theta_A$
# - Axial displacement at node $B$, $\Delta x_B$
# - Transverse displacement at node $B$, $\Delta y_B$
# - Rotation at node $B$, $\theta_B$
#
# ---
#
# **The coefficients appearing in the stiffness matrix account for axial, flexural, shear, and rigid-end effects and are defined as:**
#
# $$
# r = \dfrac{AE}{L}
# $$
#
# $$
# G = \dfrac{E}{2(1+\nu)}
# $$
#
# $$
# \beta = \dfrac{6EI}{G A L^2} \, f
# $$
#
# Where:
# - $f$ is the **shear correction factor**, accounting for the non-uniform shear stress distribution over the cross section.
#
# The remaining stiffness coefficients are expressed as:
#
# $$
# t' = \dfrac{12EI}{L^3} \, \dfrac{1}{1 + 2\beta}
# $$
#
# $$
# b' = \dfrac{6EI}{L^2} \, \dfrac{1}{1 + 2\beta}
# $$
#
# $$
# k' = \dfrac{2EI}{L} \, \dfrac{2 + \beta}{1 + 2\beta}
# $$
#
# $$
# a' = \dfrac{2EI}{L} \, \dfrac{1 - \beta}{1 + 2\beta}
# $$
#
# ---
#
# **When rigid end offsets $d_A$ and $d_B$ are present, the modified stiffness coefficients become:**
#
# $$
# b'' = b' + t' \, d_A
# $$
#
# $$
# b''' = b' + t' \, d_B
# $$
#
# $$
# a'' = a' + b'(d_A + d_B) + t' d_A d_B
# $$
#
# $$
# k'' = k' + 2 b' d_A + t' d_A^2
# $$
#
#
# $$
# k''' = k' + 2 b' d_B + t' d_B^2
# $$
#
# These expressions allow the MF element stiffness matrix to consistently incorporate:
# - Shear deformation effects through $\beta$ and $f$,
# - Rigid end offsets at both element ends,
# - Classical beam–column axial–flexural coupling.
#
# This formulation is particularly suitable for **moment-resisting frame elements** used in refined matrix-based structural analysis.

# %%
Ker = Tr @ ke @ Tr.T
Ker_df = pd.DataFrame(Ker)
Ker_df
# Out:
#          0           1            2        3           4            5
# 0  36000.0    0.000000     0.000000 -36000.0    0.000000     0.000000
# 1      0.0  128.820891   322.052228      0.0 -128.820891   322.052228
# 2      0.0  322.052228  1075.130570      0.0 -322.052228   535.130570
# 3 -36000.0    0.000000     0.000000  36000.0    0.000000     0.000000
# 4      0.0 -128.820891  -322.052228      0.0  128.820891  -322.052228
# 5      0.0  322.052228   535.130570      0.0 -322.052228  1075.130570

# %%
ejemplo2 = MF_K_T_L_Element2D(E,A,I,L,u,f,da,db)
KER = ejemplo2.stiffness_matrix_MF_EI_AE_GAf_da_db()
KER_df = pd.DataFrame(KER)
KER_df
# Out:
#          0           1            2        3           4            5
# 0  36000.0    0.000000     0.000000 -36000.0    0.000000     0.000000
# 1      0.0  128.820891   322.052228      0.0 -128.820891   322.052228
# 2      0.0  322.052228  1075.130570      0.0 -322.052228   535.130570
# 3 -36000.0    0.000000     0.000000  36000.0    0.000000     0.000000
# 4      0.0 -128.820891  -322.052228      0.0  128.820891  -322.052228
# 5      0.0  322.052228   535.130570      0.0 -322.052228  1075.130570

# %%
D2matrixF = M_visual_2D_3D(KER)
plot2dF = D2matrixF.M_visual()

# %%
ejemplo3 = MF_K_T_L_Element2D(E,A,I,L,u,f = 6/5,dA = 2.5,dB = 2.5)
KER_da_db = ejemplo3.stiffness_matrix_MF_EI_AE_GAf_da_db()
KER_da_db_df = pd.DataFrame(KER_da_db)
KER_da_db_df
# Out:
#          0           1            2        3           4            5
# 0  36000.0    0.000000     0.000000 -36000.0    0.000000     0.000000
# 1      0.0  128.820891   644.104456      0.0 -128.820891   644.104456
# 2      0.0  644.104456  3490.522281      0.0 -644.104456  2950.522281
# 3 -36000.0    0.000000     0.000000  36000.0    0.000000     0.000000
# 4      0.0 -128.820891  -644.104456      0.0  128.820891  -644.104456
# 5      0.0  644.104456  2950.522281      0.0 -644.104456  3490.522281

# %%
D3matrixF = M_visual_2D_3D(KER_da_db)
plot3dF = D3matrixF.M_visual()

# %% [markdown]
# #### **Simple Calculation of 2D MFR (Stiffness and Transformation Matrix)**

# %% [markdown]
# ##### Data

# %%
E = 2000000
I = 0.30**(4)/12
A = 0.30**(2)
L = 5
u = 0.2
f = 6/5
da = 0.30
db = 0.30
thethaE1 = 45
thethaE2 = 360-45

# %% [markdown]
# ##### Solution

# %% [markdown]
# * Element 1

# %%
Eleme1 = MF_K_T_L_Element2D(E = E, A = A, I = I, L = L, nu = u,
                            f = f, dA = da, dB = db, thetha = thethaE1)
KE1L = Eleme1.stiffness_matrix_MF_EI_AE_GAf_da_db()
TE1 = Eleme1.transformation_matrix_2D()
E1_visual = M_visual_2D_3D(TE1)
E1_visual.M_visual()

# %% [markdown]
# * Element 2

# %%
Eleme2 = MF_K_T_L_Element2D(E = E, A = A, I = I, L = L, nu = u,
                            f = f, dA = da, dB = db, thetha = thethaE2)
KE2L = Eleme2.stiffness_matrix_MF_EI_AE_GAf_da_db()
TE2 = Eleme2.transformation_matrix_2D()
E2_visual = M_visual_2D_3D(TE2)
E2_visual.M_visual()
